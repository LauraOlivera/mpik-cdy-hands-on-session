# %%
# %matplotlib inline

# %% [markdown]
# # Modeling and fitting
#
#
# ## Introduction
#
# In practice, we have to:
#
# - Read a DL4 datasets file
# - Define the `~gammapy.modeling.models.Models` to apply to the datasets from a list of `~gammapy.modeling.models.SkyModel`.
# - Create a `~gammapy.modeling.Fit` object and run it to fit the model parameters
# - Apply a `~gammapy.estimators.FluxPointsEstimator` to compute flux points for
#   the spectral part of the fit.

# %% [markdown]
# ## Setup
#
# As usual, we’ll start with some setup …

# %%
from pathlib import Path

import numpy as np
import astropy.units as u
from astropy.coordinates import SkyCoord

import matplotlib.pyplot as plt

from IPython.display import display
from gammapy.datasets import (
    Datasets,
    FluxPointsDataset,
)
from gammapy.estimators import FluxPointsEstimator
from gammapy.estimators.utils import resample_energy_edges

from gammapy.modeling import Fit
from gammapy.modeling.models import (
    PointSpatialModel,
    LogParabolaSpectralModel,
    SkyModel,
    Models
)

# %% [markdown]
# ## Read the DL4 datasets

# %% [markdown]
# To read datasets from disk you can use `Datasets.read`:

# %%
filename = "./datasets/crab_1d/datasets_crab_1d.yaml"

datasets = Datasets.read(filename)
# Out:
# /Users/qremy/Work/GitHub/gammapy/gammapy/utils/scripts.py:65: UserWarning: Checksum verification failed for datasets/crab_1d/datasets_crab_1d.yaml.
#   warnings.warn(f"Checksum verification failed for {filename}.", UserWarning)

# %%
print(datasets.names)
# Out:
# ['_hess_obs23523', '_hess_obs23526', '_hess_obs23559', '_hess_obs23592']

# %% [markdown]
# ## Define models

# %%
target_postion = SkyCoord.from_name("Crab Nebula")
spatial_model = PointSpatialModel.from_position(target_postion)
spatial_model.freeze() # frozen for 1D analysis

# we can set some limit on the parameters
# for example on the source position
shift_max = 0.2 
spatial_model.lon_0.max = spatial_model.lon_0.value + shift_max
spatial_model.lon_0.min = spatial_model.lon_0.value - shift_max
spatial_model.lat_0.max = spatial_model.lat_0.value + shift_max
spatial_model.lat_0.min = spatial_model.lat_0.value - shift_max

spectral_model = LogParabolaSpectralModel(
    amplitude=1e-12 * u.Unit("cm-2 s-1 TeV-1"),
    index=2.,
    beta=0.,
    reference=1 * u.TeV,
)
model = SkyModel(spatial_model=spatial_model, spectral_model=spectral_model, name="crab")
#model = SkyModel(spectral_model=spectral_model, name="crab")

models = Models([model])

# %% [markdown]
# Models can be saved to file :

# %%
path = Path("models")
path.mkdir(exist_ok=True)

filename = path / "models_crab.yaml"
models.write(filename, overwrite=True)

# %% [markdown]
# Alternatively you can read the models from file

# %%
filename = path / "models_crab.yaml"
models = Models.read(filename)

# %%
models[0].spectral_model
# Out:
# <pre>LogParabolaSpectralModel
#
# type    name     value         unit      ... frozen is_norm link prior
# ---- --------- ---------- -------------- ... ------ ------- ---- -----
#      amplitude 1.0000e-12 cm-2 s-1 TeV-1 ...  False    True
#      reference 1.0000e+00            TeV ...   True   False
#          alpha 2.0000e+00                ...  False   False
#           beta 0.0000e+00                ...  False   False           </pre>

# %%
models[0].spectral_model.plot([1, 30]*u.TeV)
# Out:
# <Axes: xlabel='Energy [$\\mathrm{TeV}$]', ylabel='dnde [$\\mathrm{TeV^{-1}\\,s^{-1}\\,cm^{-2}}$]'>

# %% [markdown]
# then we set the models on tha datasets

# %%
datasets.models = models

# %%
datasets[0].stat_sum()
# Out:
# 375.8664128305978

# %% [markdown]
# ## Fit spectrum
#
# Now we’ll fit a global model to the spectrum. First we do a joint
# likelihood fit to all observations. If you want to stack the
# observations see below. We will also produce a debug plot in order to
# show how the global fit matches one of the individual observations.

# %%
optimize_opts = dict(strategy=1, tolerance=0.1)
fit = Fit(optimize_opts=optimize_opts)
result_hess = fit.run(datasets=datasets)

# %% [markdown]
# We make a copy of the best-fit models to use them later.

# %%
models_best_hess = datasets.models.copy()

# %%
filename = path / "models_crab_fitted.yaml"
models_best_hess.write(filename, overwrite=True)

# %%
models[0].parameters.to_table()
# Out:
# <Table length=6>
# type    name     value         unit      ... frozen is_norm link prior
# str1    str9    float64       str14      ...  bool    bool  str1  str1
# ---- --------- ---------- -------------- ... ------ ------- ---- -----
#      amplitude 4.3645e-11 cm-2 s-1 TeV-1 ...  False    True
#      reference 1.0000e+00            TeV ...   True   False
#          alpha 2.3243e+00                ...  False   False
#           beta 1.9830e-01                ...  False   False
#          lon_0 8.3629e+01            deg ...   True   False
#          lat_0 2.2015e+01            deg ...   True   False

# %%
datasets.models.parameters.to_table()
# Out:
# <Table length=6>
# type    name     value         unit      ... frozen is_norm link prior
# str1    str9    float64       str14      ...  bool    bool  str1  str1
# ---- --------- ---------- -------------- ... ------ ------- ---- -----
#      amplitude 4.3645e-11 cm-2 s-1 TeV-1 ...  False    True
#      reference 1.0000e+00            TeV ...   True   False
#          alpha 2.3243e+00                ...  False   False
#           beta 1.9830e-01                ...  False   False
#          lon_0 8.3629e+01            deg ...   True   False
#          lat_0 2.2015e+01            deg ...   True   False

# %% [markdown]
# ## Fit quality and model residuals

# %% [markdown]
# We can access the results dictionary to see if the fit converged:

# %%
print(result_hess)
# Out:
# OptimizeResult
#
# 	backend    : minuit
# 	method     : migrad
# 	success    : True
# 	message    : Optimization terminated successfully.
# 	nfev       : 168
# 	total stat : 88.54
#
# CovarianceResult
#
# 	backend    : minuit
# 	method     : hesse
# 	success    : True
# 	message    : Hesse terminated successfully.

# %% [markdown]
# You can look into more details  of the minuit optimizer output

# %%
print(result_hess.minuit)
# Out:
# ┌─────────────────────────────────────────────────────────────────────────┐
# │                                Migrad                                   │
# ├──────────────────────────────────┬──────────────────────────────────────┤
# │ FCN = 88.54                      │              Nfcn = 168              │
# │ EDM = 2.48e-06 (Goal: 0.0002)    │            time = 0.6 sec            │
# ├──────────────────────────────────┼──────────────────────────────────────┤
# │          Valid Minimum           │        No Parameters at limit        │
# ├──────────────────────────────────┼──────────────────────────────────────┤
# │ Below EDM threshold (goal x 10)  │           Below call limit           │
# ├───────────────┬──────────────────┼───────────┬─────────────┬────────────┤
# │  Covariance   │     Hesse ok     │ Accurate  │  Pos. def.  │ Not forced │
# └───────────────┴──────────────────┴───────────┴─────────────┴────────────┘
# ┌───┬───────────────────┬───────────┬───────────┬────────────┬────────────┬─────────┬─────────┬───────┐
# │   │ Name              │   Value   │ Hesse Err │ Minos Err- │ Minos Err+ │ Limit-  │ Limit+  │ Fixed │
# ├───┼───────────────────┼───────────┼───────────┼────────────┼────────────┼─────────┼─────────┼───────┤
# │ 0 │ par_000_amplitude │   43.6    │    2.4    │            │            │         │         │       │
# │ 1 │ par_001_alpha     │   2.32    │   0.14    │            │            │         │         │       │
# │ 2 │ par_002_beta      │   0.20    │   0.09    │            │            │         │         │       │
# └───┴───────────────────┴───────────┴───────────┴────────────┴────────────┴─────────┴─────────┴───────┘
# ┌───────────────────┬───────────────────────────────────────────────────────┐
# │                   │ par_000_amplitude     par_001_alpha      par_002_beta │
# ├───────────────────┼───────────────────────────────────────────────────────┤
# │ par_000_amplitude │              6.02             0.034             0.041 │
# │     par_001_alpha │             0.034            0.0205            -0.010 │
# │      par_002_beta │             0.041            -0.010           0.00734 │
# └───────────────────┴───────────────────────────────────────────────────────┘

# %%
def plot_likelihood(results, datasets):
    total_stat = results.total_stat

    fig, axes = plt.subplots(nrows=1, ncols=3, figsize=(14, 4))

    for ax, par in zip(axes, datasets.parameters.free_parameters):
        par.scan_n_values = 17
        idx = datasets.parameters.index(par)
        name = datasets.models.parameters_unique_names[idx]
        profile = fit.stat_profile(datasets=datasets, parameter=par)
        ax.plot(profile[f"{name}_scan"], profile["stat_scan"] - total_stat)
        ax.set_xlabel(f"{par.name} [{par.unit}]")
        ax.set_ylabel("Delta TS")
        ax.set_title(f"{name}:\n {par.value:.1e} +- {par.error:.1e}")
    plt.show()

# %%
p = models[0].parameters["amplitude"]

# %%
print(p.scan_n_values)
print(p.scan_min)
print(p.scan_max)
# Out:
# 11
# 3.873796331527626e-11
# 4.8552317075244235e-11

# %%
p.scan_values
# Out:
# array([3.87379633e-11, 3.96227032e-11, 4.05276497e-11, 4.14532644e-11,
#        4.24000193e-11, 4.33683972e-11, 4.43588920e-11, 4.53720088e-11,
#        4.64082642e-11, 4.74681868e-11, 4.85523171e-11])

# %%
plot_likelihood(result_hess, datasets)

# %%
datasets_1obs = Datasets([datasets[0].copy()])
datasets_1obs.models = models_best_hess.copy()
result_hess_1obs = fit.run(datasets_1obs)
plot_likelihood(result_hess_1obs, datasets_1obs)

# %% [markdown]
# and check the best-fit parameters

# %%
display(result_hess.models.to_parameters_table())
# Out:
# <Table length=6>
# model type    name     value         unit      ... frozen is_norm link prior
#  str4 str1    str9    float64       str14      ...  bool    bool  str1  str1
# ----- ---- --------- ---------- -------------- ... ------ ------- ---- -----
#  crab      amplitude 4.3645e-11 cm-2 s-1 TeV-1 ...  False    True
#  crab      reference 1.0000e+00            TeV ...   True   False
#  crab          alpha 2.3243e+00                ...  False   False
#  crab           beta 1.9830e-01                ...  False   False
#  crab          lon_0 8.3629e+01            deg ...   True   False
#  crab          lat_0 2.2015e+01            deg ...   True   False

# %%
datasets[0].models[0].spectral_model.plot([0.3, 30]*u.TeV)
# Out:
# <Axes: xlabel='Energy [$\\mathrm{TeV}$]', ylabel='dnde [$\\mathrm{TeV^{-1}\\,s^{-1}\\,cm^{-2}}$]'>

# %% [markdown]
# A simple way to inspect the model residuals is using the function
# `~SpectrumDataset.plot_fit()`

# %%
ax_spectrum, ax_residuals = datasets[0].plot_fit()
ax_spectrum.set_ylim(0.1, 40)
datasets[0].plot_masks(ax=ax_spectrum)
plt.show()

# %% [markdown]
# For more ways of assessing fit quality, please refer to the dedicated tutorial :
# https://docs.gammapy.org/1.2/tutorials/api/fitting.html

# %% [markdown]
# ## Compute Flux Points
#
# To round up our analysis we can compute flux points by fitting the norm
# of the global model in energy bands.
# We can utilise the `~gammapy.estimators.utils.resample_energy_edges`
# for defining the energy bins in which the minimum number of `sqrt_ts` is 2.
# To do so we first stack the individual datasets, only for obtaining the energies:

# %%
dataset_stacked = datasets.stack_reduce()
energy_edges = resample_energy_edges(dataset_stacked, conditions={"sqrt_ts_min": 2})

# %% [markdown]
# Now we create an instance of the
# `~gammapy.estimators.FluxPointsEstimator`, by passing the dataset and
# the energy binning:

# %%
fpe = FluxPointsEstimator(
    energy_edges=energy_edges, source="crab", selection_optional="all"
)
flux_points_hess = fpe.run(datasets=datasets)

# %% [markdown]
# Here is a the table of the resulting flux points:

# %%
display(flux_points_hess.to_table(sed_type="dnde", formatted=True))
# Out:
# <Table length=15>
#  e_ref   e_min   e_max  ... success   norm_scan        stat_scan
#   TeV     TeV     TeV   ...
# float64 float64 float64 ...   bool   float64[11]      float64[11]
# ------- ------- ------- ... ------- -------------- ------------------
#   0.659   0.590   0.737 ...    True 0.200 .. 5.000  62.312 .. 234.240
#   0.823   0.737   0.920 ...    True 0.200 .. 5.000 138.832 .. 442.156
#   1.028   0.920   1.148 ...    True 0.200 .. 5.000 104.045 .. 388.506
#   1.283   1.148   1.434 ...    True 0.200 .. 5.000  76.601 .. 317.487
#   1.602   1.434   1.790 ...    True 0.200 .. 5.000  84.148 .. 228.970
#   2.000   1.790   2.235 ...    True 0.200 .. 5.000  61.416 .. 203.100
#     ...     ...     ... ...     ...            ...                ...
#   4.859   4.348   5.429 ...    True 0.200 .. 5.000   30.408 .. 76.977
#   6.066   5.429   6.778 ...    True 0.200 .. 5.000   17.053 .. 44.511
#   7.573   6.778   8.462 ...    True 0.200 .. 5.000   17.442 .. 29.850
#   9.454   8.462  10.564 ...    True 0.200 .. 5.000   12.831 .. 19.111
#  11.803  10.564  13.189 ...    True 0.200 .. 5.000   12.232 .. 17.978
#  22.968  13.189  40.000 ...    True 0.200 .. 5.000   10.361 .. 32.093

# %% [markdown]
# Now we plot the flux points and their likelihood profiles. For the
# plotting of upper limits we choose a threshold of TS < 4.

# %%
fig, ax = plt.subplots()
flux_points_hess.plot(ax=ax, sed_type="e2dnde", color="darkorange")
flux_points_hess.plot_ts_profiles(ax=ax, sed_type="e2dnde")
plt.show()

# %% [markdown]
# The final plot with the best fit model, flux points and residuals can be
# quickly made like this:

# %%
flux_points_dataset_hess = FluxPointsDataset(data=flux_points_hess, models=models_best_hess)
flux_points_dataset_hess.plot_fit()
plt.show()

# %% [markdown]
# **In the next notebook we add data from other instruments and perform a joint fit.**
